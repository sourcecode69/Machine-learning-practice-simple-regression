# %% [markdown]
# <a href="https://colab.research.google.com/github/sourcecode69/Machine-learning-practice-simple-regression/blob/main/2.Understanding_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %%
df.shape
#how big is the data
# Out:
# (891, 12)

# %%
df.sample(5)
#this gives random data
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 52            53         1       1  Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 2              3         1       3                    Heikkinen, Miss. Laina
# 100          101         0       3                   Petranec, Miss. Matilda
# 199          200         0       2    Yrois, Miss. Henriette ("Mrs Harbeck")
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 868    male   NaN      0      0            345777   9.5000   NaN        S
# 52   female  49.0      1      0          PC 17572  76.7292   D33        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 100  female  28.0      0      0            349245   7.8958   NaN        S
# 199  female  24.0      0      0            248747  13.0000   NaN        S

# %%
df.info()
#info about data type and how much space it occupy
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#are there missing values

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
#this shows data in mathematical form
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#to check the duplicate value
df.duplicated().sum()
# Out:
# 0

# %%
#correaltion. btw the colums
df.corr()['Survived']
# Out:
# <ipython-input-82-1093399f7ccc>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Survived']
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
